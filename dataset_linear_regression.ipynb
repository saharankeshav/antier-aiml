# %%
import pandas as pd

# %%
df = pd.read_csv("Student_Performance.csv")
# print(df.head())
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df = df.drop_duplicates()
# print(df.shape)
# Out:
# (9873, 6)

# %%
data = df[['Hours Studied', 'Performance Index']]
data.head()
# Out:
#    Hours Studied  Performance Index
# 0              7               91.0
# 1              4               65.0
# 2              8               45.0
# 3              5               36.0
# 4              7               66.0

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train , y_test = train_test_split(X,y,test_size = 0.2)
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
print(model.score(X_test,y_test))
# Out:
# 0.12641524543951532

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.scatter(df['Hours Studied'], df['Performance Index'])

# %%
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 plt.show()
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/matplotlib/_api/__init__.py:318, in caching_module_getattr.<locals>.__getattr__(name)
#     316 if name in props:
#     317     return props[name].__get__(instance)
# --> 318 raise AttributeError(
#     319     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
print(model.predict([[30]]))
# Out:
# [125.61289419]
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(model.predict([[10]]))
# Out:
# [69.28128525]
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import numpy as np

x_line = np.linspace(df['Hours Studied'].min(), df['Hours Studied'].max(), 100)
y_line = model.predict(x_line.reshape(-1, 1))

plt.scatter(df['Hours Studied'], df['Performance Index'], label='Data')
plt.plot(x_line, y_line, color='red', label='Regression Line')
plt.xlabel('Hours Studied')
plt.ylabel('Performance Index')
plt.legend()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# confusion matrix

# %%
# matrix designed between the original data and predicted data , also known as evolution matrix and error matrix

# %%
# accuray = tn+tp/tn+tp+fp+fn

# %%
# error = fp+fn/n

# %%
# precision = tp/tp+np

# %%
# recall = tp/tp+fn

# %%
# r inversly to fn
# f1 score = 2 x precison*recall/precision+recall

# %%
# precison - help us to measure the ability to classfy the samples in models

# %% [raw]
# recall - helps us to measure , how many the samples were correctkly classify by ml model

# %%
# both - fp and fn are dangerous , sometime we have to low the false posiitive and false negitive , sometime situation occurs where we need to low both false positive and falase negetive , sometime no idea whther we shpould low positive or false negetive(less knowlege of domain)

# %%
# then we move to f1 score - harmonic mean od precision and recall , it takes both false positive and false negetive in account, it performs well on an imbalanced data

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import  LogisticRegression

# %%
from sklearn.metrics import(accuracy_score,confusion_matrix,ConfusionMatrixDisplay,classification_report)

# %%
iris = load_iris()

# %%
x = iris.data

# %%
y= iris.target

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)

# %%
model = LogisticRegression(max_iter = 200)

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=200)

# %%
y_pred = model.predict(x_test)

# %%
accuracy = accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.9666666666666667

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[10,  0,  0],
#        [ 0,  9,  1],
#        [ 0,  0, 10]])

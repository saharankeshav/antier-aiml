# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({
    "maths": [4, 6, 7, 5, 6],
    "cs": [3, 7, 8, 5, 9],
    "result": ["fail", "pass", "pass", "fail", "pass"]
})

# %%
df
# Out:
#    maths  cs result
# 0      4   3   fail
# 1      6   7   pass
# 2      7   8   pass
# 3      5   5   fail
# 4      6   9   pass

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,2]

# %%
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 X
#
# NameError: name 'X' is not defined

# %%
x
# Out:
#    maths  cs
# 0      4   3
# 1      6   7
# 2      7   8
# 3      5   5
# 4      6   9

# %%
y
# Out:
# 0    fail
# 1    pass
# 2    pass
# 3    fail
# 4    pass
# Name: result, dtype: object

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
classifier = KNeighborsClassifier(n_neighbors=5)

# %%
classifier.fit(x,y)
# Out:
# KNeighborsClassifier()

# %%
prediction = classifier.predict([[6,8]])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
prediction
# Out:
# array(['pass'], dtype=object)

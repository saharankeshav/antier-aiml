# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("position_salaries.csv")

# %%
df
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
x = df.iloc[:,1:2]

# %%
y = df.iloc[:,-1]

# %%
plt.scatter(x,y)

# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
# sns.lmplot() IS A seaborn function used to plot a scatterplot + regrewesion line in one go

# %%
sns.lmplot(x="Level" , y ="Salary",data = df)

# %%
from sklearn.linear_model import LinearRegression

# %%
rg = LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree = 2)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.2)

# %%
# x_new = poly.fit_transform(x_train)
# print(x_new)

# %%
# rg.fit(x_new,y_train)
# x_new = poly.fit_transform(x_train)

# %%
# y_pred = rg.predict(poly.fit_transform(x_test))

# %%
from sklearn.metrics import r2_score

# %%
# r2_score(y_test,y_pred)

# %%
# plt.scatter(x,y,color='blue')
# plt.plot(x,rg.predict(poly.fit_transform(x)),color='red')

# %%
dsf = pd.read_csv("Ice_cream selling data.csv")

# %%
x = dsf.iloc[:,0:1]

# %%
y = dsf.iloc[:,-1]

# %%
plt.scatter(x,y)

# %%
sns.lmplot(x="Temperature (°C)" , y="Ice Cream Sales (units)", data = dsf)

# %%
from sklearn.linear_model import PolynomialFeatures
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 from sklearn.linear_model import PolynomialFeatures
#
# ImportError: cannot import name 'PolynomialFeatures' from 'sklearn.linear_model' (/Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/linear_model/__init__.py)

# %%
rg = LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree = 2)

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.2)

# %%
x_new = poly.fit_transform(x_train)
print(x_new)
# Out:
# [[ 1.00000000e+00 -7.73330043e-01  5.98039356e-01]
#  [ 1.00000000e+00 -6.73752802e-01  4.53942838e-01]
#  [ 1.00000000e+00  1.35981267e+00  1.84909051e+00]
#  [ 1.00000000e+00  3.27004407e+00  1.06931882e+01]
#  [ 1.00000000e+00  4.13086796e+00  1.70640701e+01]
#  [ 1.00000000e+00  8.60769873e-03  7.40924775e-05]
#  [ 1.00000000e+00  1.99931037e+00  3.99724195e+00]
#  [ 1.00000000e+00 -3.61564977e-02  1.30729232e-03]
#  [ 1.00000000e+00 -1.66034773e+00  2.75675458e+00]
#  [ 1.00000000e+00 -3.94966109e+00  1.55998227e+01]
#  [ 1.00000000e+00  2.31859124e+00  5.37586534e+00]
#  [ 1.00000000e+00 -3.10844012e+00  9.66239999e+00]
#  [ 1.00000000e+00 -2.28826400e+00  5.23615213e+00]
#  [ 1.00000000e+00 -1.17312327e+00  1.37621820e+00]
#  [ 1.00000000e+00 -2.11186969e+00  4.45999359e+00]
#  [ 1.00000000e+00  2.83176021e+00  8.01886589e+00]
#  [ 1.00000000e+00 -4.66226268e+00  2.17366933e+01]
#  [ 1.00000000e+00  1.49244574e-01  2.22739429e-02]
# ...

# %%
rg.fit(x_new,y_train)
x_new = poly.fit_transform(x_train)

# %%
y_pred = rg.predict(poly.fit_transform(x_test))

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# -0.3976769344903568

# %%
plt.scatter(x,y,color='blue')
plt.plot(x,rg.predict(poly.fit_transform(x)),color='red')
